# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# # From Model to Production

# %% [markdown]
# ## The Practice of Deep Learning

# %% [markdown]
# ### Starting Your Project

# %% [markdown]
# ### The State of Deep Learning

# %% [markdown]
# #### Computer vision

# %% [markdown]
# #### Text (natural language processing)

# %% [markdown]
# #### Combining text and images

# %% [markdown]
# #### Tabular data

# %% [markdown]
# #### Recommendation systems

# %% [markdown]
# #### Other data types

# %% [markdown]
# ### The Drivetrain Approach

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# # clean
# To download images with Bing Image Search, sign up at Microsoft for a free account. You will be given a key, which you can copy and enter in a cell as follows (replacing 'XXX' with your key and executing it):

# %%
key = os.environ.get('AZURE_SEARCH_KEY', 'db6ab067d3c64b1b86ff4a7d7b0d8a9e')

# %%
search_images_bing
# Out:
# <function fastbook.search_images_bing>

# %%
results = search_images_bing(key, 'grizzly bear')
ims = results.attrgot('content_url')
len(ims)
# Out:
# 150

# %%
#hide
ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %%
ims
# Out:
# ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %%
dest = 'images/grizzly.jpg'
# dest = 'images/pong.jpg'
download_url(ims[0], dest)

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=108x128 at 0x7F715E941E80>

# %%
bear_types = 'grizzly','black','teddy','panda'
path = Path('bears')

# %%
if not path.exists():
    path.mkdir()
    for o in bear_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} bear')
        download_images(dest, urls=results.attrgot('content_url'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#566) [Path('bears/grizzly/00000065.jpg'),Path('bears/grizzly/00000045.jpg'),Path('bears/grizzly/00000131.jpg'),Path('bears/grizzly/00000002.jpg'),Path('bears/grizzly/00000145.jpg'),Path('bears/grizzly/00000066.jpg'),Path('bears/grizzly/00000072.jpg'),Path('bears/grizzly/00000006.jpg'),Path('bears/grizzly/00000028.jpg'),Path('bears/grizzly/00000070.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# █
# (#0) []

# %%
failed.map(Path.unlink);

# %% [markdown]
# ### Sidebar: Getting Help in Jupyter Notebooks

# %% [markdown]
# ### End sidebar

# %% [markdown]
# ## From Data to DataLoaders

# %%
# bears = DataBlock(
#     blocks=(ImageBlock, CategoryBlock), 
#     get_items=get_image_files, 
#     splitter=RandomSplitter(valid_pct=0.2, seed=42),
#     get_y=parent_label,
#     item_tfms=Resize(128))

bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128)
)

# %%
dls = bears.dataloaders(path)

# %%
dls.valid.show_batch(max_n=5, nrows=1)

# %%
# bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
# dls = bears.dataloaders(path)
# dls.valid.show_batch(max_n=4, nrows=1)

bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=5, nrows=1)

# %%
# bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
# dls = bears.dataloaders(path)
# dls.valid.show_batch(max_n=4, nrows=1)

bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=5, nrows=1)

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.2))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=10, nrows=1, unique=True)

# %% [markdown]
# ### Data Augmentation

# %%
# bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# ## Training Your Model, and Using It to Clean Your Data

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)

# %%
# learn = cnn_learner(dls, resnet18, metrics=error_rate)
# learn.fine_tune(4)

learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /home/ec2-user/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=46827520.0), HTML(value='')))
# epoch     train_loss  valid_loss  error_rate  time
# 0         1.470302    0.097298    0.035398    00:14
# epoch     train_loss  valid_loss  error_rate  time
# 0         0.184665    0.060272    0.017699    00:14
# 1         0.140383    0.046022    0.026549    00:15
# 2         0.113525    0.055835    0.026549    00:15
# 3         0.086863    0.046992    0.026549    00:14

# %%
# interp = ClassificationInterpretation.from_learner(learn)
# interp.plot_confusion_matrix()

interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# █

# %%
interp.plot_top_losses(5, nrows=1)

# %%
# cleaner = ImageClassifierCleaner(learn)
# cleaner

cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# █
# VBox(children=(Dropdown(options=('black', 'grizzly', 'panda', 'teddy'), value='black'), Dropdown(options=('Tra…

# %%
#hide
# for idx in cleaner.delete(): 
#     cleaner.fns[idx].unlink()

# for idx,cat in cleaner.change(): 
#     shutil.move(str(cleaner.fns[idx]), path/cat)

cleaner.delete()

for idx in cleaner.delete():
    cleaner.fns[idx].unlink()

# %% [markdown]
# ## Turning Your Model into an Online Application

# %% [markdown]
# ### Using the Model for Inference

# %%
# learn.export()
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
# learn_inf = load_learner(path/'export.pkl')
learn_inf = load_learner(path/'export.pkl')

# %%
# learn_inf.predict('images/grizzly.jpg')
predict_result = learn_inf.predict('images/grizzly.jpg')
print(predict_result)
print(f'Predict result {predict_result[0]}.')
print(f'With Prob {predict_result[2][1].item():.6f}')
# Out:
# ('grizzly', tensor(1), tensor([7.9570e-07, 1.0000e+00, 3.0369e-07, 6.7837e-07]))
# Predict result grizzly.
# With Prob 0.999998

# %%
# learn_inf.dls.vocab
learn_inf.dls.vocab
# Out:
# (#4) ['black','grizzly','panda','teddy']

# %% [markdown]
# ### Creating a Notebook App from the Model

# %%
# btn_upload = widgets.FileUpload()
# btn_upload
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/grizzly.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])
img.to_thumb(192)
# Out:
# <PIL.Image.Image image mode=RGB size=192x192 at 0x7F7154024A58>

# %%
# out_pl = widgets.Output()
# out_pl.clear_output()
# with out_pl: display(img.to_thumb(128,128))
# out_pl

out_pl = widgets.Output()
out_pl.clear_output()
with out_pl:
    display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)
print(pred)
print(pred_idx)
print(probs)
# Out:
# panda
# tensor(2)
# tensor([9.2582e-08, 3.5117e-08, 1.0000e+00, 2.0139e-06])

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: panda; Probability: 1.0000')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())
# █
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-e85f52797c49> in on_click_classify(change)
#       1 def on_click_classify(change):
# ----> 2     img = PILImage.create(btn_upload.data[-1])
#       3     out_pl.clear_output()
#       4     with out_pl: display(img.to_thumb(128,128))
#       5     pred,pred_idx,probs = learn_inf.predict(img)
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-e85f52797c49> in on_click_classify(change)
#       1 def on_click_classify(change):
# ----> 2     img = PILImage.create(btn_upload.data[-1])
#       3     out_pl.clear_output()
#       4     with out_pl: display(img.to_thumb(128,128))
#       5     pred,pred_idx,probs = learn_inf.predict(img)
#
# IndexError: list index out of range
# █

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
# VBox([widgets.Label('Select your bear!'), 
#       btn_upload, btn_run, out_pl, lbl_pred])

VBox([
    widgets.Label('Select your bear to predict!'),
    btn_upload,
    btn_run,
    out_pl,
    lbl_pred
])
# Out:
# VBox(children=(Label(value='Select your bear to predict!'), FileUpload(value={}, description='Upload'), Button…
# █

# %% [markdown]
# ### Turning Your Notebook into a Real App

# %%
#hide
# !pip install voila
# !jupyter serverextension enable voila --sys-prefix
# Out:
# Collecting voila
#   Using cached voila-0.2.3-py3-none-any.whl (6.9 MB)
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from voila) (0.5.0)
# Requirement already satisfied: jupyter-server<2.0.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from voila) (1.0.4)
# Requirement already satisfied: nbconvert<7,>=6.0.0 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from voila) (6.0.7)
# Requirement already satisfied: jupyter-client<7,>=6.1.3 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from voila) (6.1.7)
# Requirement already satisfied: nbformat>=5.0 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbclient<0.6,>=0.4.0->voila) (5.0.7)
# Requirement already satisfied: async-generator in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: nest-asyncio in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.4.1)
# Requirement already satisfied: traitlets>=4.2 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbclient<0.6,>=0.4.0->voila) (4.3.3)
# Requirement already satisfied: Send2Trash in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (19.0.2)
# Requirement already satisfied: jupyter-core>=4.4.0 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (4.6.3)
# Requirement already satisfied: tornado>=5.0 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (6.0.4)
# Requirement already satisfied: ipython-genutils in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (2.11.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.9.1)
# Requirement already satisfied: prometheus-client in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.8.0)
# Requirement already satisfied: jupyterlab-pygments in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbconvert<7,>=6.0.0->voila) (0.1.2)
# Requirement already satisfied: testpath in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbconvert<7,>=6.0.0->voila) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: pygments>=2.4.1 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbconvert<7,>=6.0.0->voila) (2.7.1)
# Requirement already satisfied: bleach in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbconvert<7,>=6.0.0->voila) (3.2.1)
# Requirement already satisfied: defusedxml in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbconvert<7,>=6.0.0->voila) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.1 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (3.2.0)
# Requirement already satisfied: decorator in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from traitlets>=4.2->nbclient<0.6,>=0.4.0->voila) (4.4.2)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from traitlets>=4.2->nbclient<0.6,>=0.4.0->voila) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jinja2->jupyter-server<2.0.0,>=0.3.0->voila) (1.1.1)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=0.3.0->voila) (0.6.0)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (20.4)
# Requirement already satisfied: webencodings in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (2.0.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (49.6.0.post20200917)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (20.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (3.2.0)
# Installing collected packages: voila
# Successfully installed voila-0.2.3
# Enabling: voila
# - Writing config: /home/ec2-user/anaconda3/envs/JupyterSystemEnv/etc/jupyter
#     - Validating...
#       voila 0.2.3 OK

# %% [markdown]
# ### Deploying your app

# %% [markdown]
# ## How to Avoid Disaster

# %% [markdown]
# ### Unforeseen Consequences and Feedback Loops

# %% [markdown]
# ## Get Writing!

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Provide an example of where the bear classification model might work poorly in production, due to structural or style differences in the training data.?
# **ANS** if use bear data from internel it not enough for real world, bear behide brush or in low light bear, it called out of domain.
# 1. Where do text models currently have a major deficiency?
# **ANS**
# 1. What are possible negative societal implications of text generation models?
# **ANS** Fake news. Fake information and hard to verify.
# 1. In situations where a model might make mistakes, and those mistakes could be harmful, what is a good alternative to automating a process?
# **ANS**
# 1. What kind of tabular data is deep learning particularly good at?
# **ANS**
# 1. What's a key downside of directly using a deep learning model for recommendation systems?
# **ANS**
# 1. What are the steps of the Drivetrain Approach?
# **ANS**
# 1. How do the steps of the Drivetrain Approach map to a recommendation system?
# **ANS**
# 1. Create an image recognition model using data you curate, and deploy it on the web.
# 1. What is `DataLoaders`?
# **ANS**
# 1. What four things do we need to tell fastai to create `DataLoaders`?
# **ANS**
# 1. What does the `splitter` parameter to `DataBlock` do?
# **ANS**
# 1. How do we ensure a random split always gives the same validation set?
# **ANS**
# 1. What letters are often used to signify the independent and dependent variables?
# **ANS**
# 1. What's the difference between the crop, pad, and squish resize approaches? When might you choose one over the others?
# **ANS**
# 1. What is data augmentation? Why is it needed?
# **ANS**
# 1. What is the difference between `item_tfms` and `batch_tfms`?
# **ANS**
# 1. What is a confusion matrix?
# **ANS**
# 1. What does `export` save?
# **ANS**
# 1. What is it called when we use a model for getting predictions, instead of training?
# **ANS**
# 1. What are IPython widgets?
# **ANS**
# 1. When might you want to use CPU for deployment? When might GPU be better?
# **ANS**
# 1. What are the downsides of deploying your app to a server, instead of to a client (or edge) device such as a phone or PC?
# **ANS**
# 1. What are three examples of problems that could occur when rolling out a bear warning system in practice?
# **ANS**
# 1. What is "out-of-domain data"?
# **ANS**
# 1. What is "domain shift"?
# **ANS**
# 1. What are the three steps in the deployment process?
# **ANS**

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Consider how the Drivetrain Approach maps to a project or problem you're interested in.
# 1. When might it be best to avoid certain types of data augmentation?
# 1. For a project you're interested in applying deep learning to, consider the thought experiment "What would happen if it went really, really well?"
# 1. Start a blog, and write your first blog post. For instance, write about what you think deep learning might be useful for in a domain you're interested in.
